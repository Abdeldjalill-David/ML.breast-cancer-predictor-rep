# %% [markdown]
# # **BREAST CANCER DETECTION**
# ## **IMPORT LIBRERIES**

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score , classification_report , confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder

# %% [markdown]
# ## **loading data**

# %%
df=pd.read_csv('/content/data.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %% [markdown]
# ## **DATA PREPARING**

# %%
y=df['diagnosis']
x=df.drop(columns='diagnosis',axis=1)

# %%
x=df.drop(columns='Unnamed: 32',axis=1)
x
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
y
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %% [markdown]
# ## **spliting data**

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.fit_transform(y_test)
categorical_cols = x.select_dtypes(include=['object']).columns
encoder = OrdinalEncoder()
x_train[categorical_cols] = encoder.fit_transform(x_train[categorical_cols])
x_test[categorical_cols] = encoder.transform(x_test[categorical_cols])

# %% [markdown]
# ## **INITIALIZE THE MODEL**

# %%
model=LogisticRegression(max_iter=1000)

# %%
from sklearn.model_selection import GridSearchCV

# Define the parameter grid to search
param_grid = {
    'C': [0.1, 1, 10, 100]
}

# %% [markdown]
# ## **TRAIN THE MODEL**

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# ## **MAKE PREDICTIONS**

# %%
y_trained_pred=model.predict(x_train)
y_test_pred=model.predict(x_test)

# %% [markdown]
# ## **EVALUATE THE MODEL**

# %%
#TRAINING SET AVALUATE
train_accuracy=accuracy_score(y_train, y_trained_pred)
train_report=classification_report(y_train, y_trained_pred , zero_division=1)
train_conf_matrics=confusion_matrix(y_train, y_trained_pred)
#TESTING SET EVALUATE
test_accuracy=accuracy_score(y_test, y_test_pred)
test_report=classification_report(y_test, y_test_pred , zero_division=1)
test_conf_matrics=confusion_matrix(y_test, y_test_pred)

# %%
print ('train accuracy' ,train_accuracy)
print ('train_report', train_report)
print ( 'train confusion matrics',train_conf_matrics)
print ( 'test accuracy',test_accuracy)
print ( 'test report',test_report)
print ( 'test confusion matrix',test_conf_matrics)
# Out:
# train accuracy 0.6285714285714286
# train_report               precision    recall  f1-score   support
#
#            0       0.63      1.00      0.77       286
#            1       1.00      0.00      0.00       169
#
#     accuracy                           0.63       455
#    macro avg       0.81      0.50      0.39       455
# weighted avg       0.77      0.63      0.49       455
#
# train confusion matrics [[286   0]
#  [169   0]]
# test accuracy 0.6228070175438597
# test report               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.77        71
#            1       1.00      0.00      0.00        43
#
#     accuracy                           0.62       114
#    macro avg       0.81      0.50      0.38       114
# weighted avg       0.77      0.62      0.48       114
#
# test confusion matrix [[71  0]
#  [43  0]]
